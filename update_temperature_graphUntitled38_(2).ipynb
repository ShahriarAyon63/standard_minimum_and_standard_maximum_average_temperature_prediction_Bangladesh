# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# Actual temperature values for 2022
actual_temps = np.array([
    23.13333333, 21.68333333, 21.85833333, 21.50833333, 21.84166667,
    21.44166667, 21.44166667, 21.65833333, 21.5, 22.625, 21.80833333,
    21.09166667, 21.04166667, 21.725, 22.70833333, 22.4, 21.54166667,
    22.18333333, 22.81666667, 22.675, 22.39166667, 21.08333333, 20.13333333,
    21.23333333, 21.18333333, 21.86666667, 20.825, 21.83333333, 21.10833333,
    20.69166667, 20.45833333, 19.83333333, 20.58333333, 20.28333333,
    22.54166667, 22.55833333, 22.15833333, 21.225, 21.19166667, 21.59166667,
    22.025, 22.30833333, 22.10833333, 31.65833333, 31.225, 31.45833333,
    31.09166667, 31.11666667, 30.50833333, 30.53333333, 30.425, 30.4,
    31.36666667, 31.53333333, 32.35833333, 31.41666667, 31.25833333, 31.725,
    31.325, 31.50833333, 31.23333333, 31.33333333, 31.16666667, 31.56666667,
    30.61666667, 31.36666667, 31.76666667, 31.76666667, 31.11666667, 30.56666667,
    30.98333333, 30.38333333, 30.58333333, 30.875, 30.25, 29.79166667,
    29.81666667, 31.65833333, 31.65, 31.325, 31.75833333, 31.6, 31.41666667,
    31.575, 31.5, 31.40833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    23.42, 21.91, 21.92, 21.51, 21.69, 21.5, 21.5, 21.86, 21.79, 22.69,
    21.71, 21.36, 21.04, 21.68, 22.8, 22.33, 21.48, 22.16, 22.91, 24.44,
    22.63, 21.23, 20.03, 21.33, 21.25, 21.83, 21.05, 21.82, 21.47, 20.9,
    20.64, 20.69, 20.69, 20.67, 22.44, 22.38, 21.99, 20.86, 21.11, 21.5,
    21.57, 22.23, 21.9, 32.21, 31.83, 32.03, 31.4, 31.49, 31.22, 31.25,
    31.21, 31.43, 31.75, 32.33, 35.13, 32.34, 31.88, 32.25, 31.86, 32.2,
    31.92, 31.74, 31.58, 31.71, 31.56, 31.8, 32.38, 32.52, 32.09, 31.38,
    31.26, 31.41, 31.75, 32.07, 31.42, 30.81, 31.12, 32.06, 31.89, 31.66,
    31.9, 32.15, 32.28, 32, 31.92, 31.8
])

# Reshape the data to fit the model
actual_temps = actual_temps.reshape(-1, 1)
predicted_temps = predicted_temps.reshape(-1, 1)

# Train a linear regression model
model = LinearRegression()
model.fit(predicted_temps, actual_temps)

# Predict actual temperatures based on predicted temperatures
predicted_actual_temps = model.predict(predicted_temps)

# Plot the graph
plt.scatter(predicted_temps, actual_temps, color='blue', label='Actual Temperatures')
plt.plot(predicted_temps, predicted_actual_temps, color='red', linewidth=2, label='Linear Regression')

plt.title('Actual vs Predicted Temperatures (2022 vs 1981-2010)')
plt.xlabel('Predicted Temperatures (1981-2010)')
plt.ylabel('Actual Temperatures (2022)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from sklearn.linear_model import LinearRegression

# Reshape the data to fit the model
actual_temps = actual_temps.reshape(-1, 1)
predicted_temps = predicted_temps.reshape(-1, 1)

# Train a linear regression model
model = LinearRegression()
model.fit(predicted_temps, actual_temps)

# Predict actual temperatures based on predicted temperatures
predicted_actual_temps = model.predict(predicted_temps)

# Create a 3D plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot for actual temperatures
ax.scatter(predicted_temps, actual_temps, zs=0, color='blue', label='Actual Temperatures')

# Scatter plot for predicted temperatures
ax.scatter(predicted_temps, predicted_actual_temps, zs=1, color='red', label='Predicted Temperatures (Linear Regression)')

# Set labels and title
ax.set_xlabel('Predicted Temperatures (1981-2010)')
ax.set_ylabel('Actual Temperatures (2022)')
ax.set_zlabel('Temperature')
ax.set_title('Actual vs Predicted Temperatures (2022 vs 1981-2010)')

# Add a legend
ax.legend()

# Show the 3D plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    23.13333333, 21.68333333, 21.85833333, 21.50833333, 21.84166667,
    21.44166667, 21.44166667, 21.65833333, 21.5, 22.625, 21.80833333,
    21.09166667, 21.04166667, 21.725, 22.70833333, 22.4, 21.54166667,
    22.18333333, 22.81666667, 22.675, 22.39166667, 21.08333333, 20.13333333,
    21.23333333, 21.18333333, 21.86666667, 20.825, 21.83333333, 21.10833333,
    20.69166667, 20.45833333, 19.83333333, 20.58333333, 20.28333333,
    22.54166667, 22.55833333, 22.15833333, 21.225, 21.19166667, 21.59166667,
    22.025, 22.30833333, 22.10833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    23.42, 21.91, 21.92, 21.51, 21.69, 21.5, 21.5, 21.86, 21.79, 22.69,
    21.71, 21.36, 21.04, 21.68, 22.8, 22.33, 21.48, 22.16, 22.91, 24.44,
    22.63, 21.23, 20.03, 21.33, 21.25, 21.83, 21.05, 21.82, 21.47, 20.9,
    20.64, 20.69, 20.69, 20.67, 22.44, 22.38, 21.99, 20.86, 21.11, 21.5,
    21.57, 22.23, 21.9
])

# Plot the graph
plt.plot(actual_temps, label='Actual Minimum Average Temperatures (2022)')
plt.plot(predicted_temps, label='Predicted Minimum Average Temperatures(1981-2010)')
plt.xlabel('Different Stations')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Minimum Average Temperatures')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    23.13333333, 21.68333333, 21.85833333, 21.50833333, 21.84166667,
    21.44166667, 21.44166667, 21.65833333, 21.5, 22.625, 21.80833333,
    21.09166667, 21.04166667, 21.725, 22.70833333, 22.4, 21.54166667,
    22.18333333, 22.81666667, 22.675, 22.39166667, 21.08333333, 20.13333333,
    21.23333333, 21.18333333, 21.86666667, 20.825, 21.83333333, 21.10833333,
    20.69166667, 20.45833333, 19.83333333, 20.58333333, 20.28333333,
    22.54166667, 22.55833333, 22.15833333, 21.225, 21.19166667, 21.59166667,
    22.025, 22.30833333, 22.10833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    23.42, 21.91, 21.92, 21.51, 21.69, 21.5, 21.5, 21.86, 21.79, 22.69,
    21.71, 21.36, 21.04, 21.68, 22.8, 22.33, 21.48, 22.16, 22.91, 24.44,
    22.63, 21.23, 20.03, 21.33, 21.25, 21.83, 21.05, 21.82, 21.47, 20.9,
    20.64, 20.69, 20.69, 20.67, 22.44, 22.38, 21.99, 20.86, 21.11, 21.5,
    21.57, 22.23, 21.9
])

# Plot the graph using vector graphics (PDF format)
plt.figure(figsize=(10, 6))
plt.plot(actual_temps, label='Actual Minimum Average Temperatures (2022)')
plt.plot(predicted_temps, label='Predicted Minimum Average Temperatures(1981-2010)')
plt.xlabel('Different Stations')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Minimum Average Temperatures')
plt.legend()
plt.tight_layout()

# Save the figure in PDF format
plt.savefig('temperature_comparison.pdf', format='pdf')

# Display the figure
plt.show()

# Figure caption
figure_caption = "Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010."
print(f"\nFigure 1: {figure_caption}")
# Out:
# Figure 1: Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    23.13333333, 21.68333333, 21.85833333, 21.50833333, 21.84166667,
    21.44166667, 21.44166667, 21.65833333, 21.5, 22.625, 21.80833333,
    21.09166667, 21.04166667, 21.725, 22.70833333, 22.4, 21.54166667,
    22.18333333, 22.81666667, 22.675, 22.39166667, 21.08333333, 20.13333333,
    21.23333333, 21.18333333, 21.86666667, 20.825, 21.83333333, 21.10833333,
    20.69166667, 20.45833333, 19.83333333, 20.58333333, 20.28333333,
    22.54166667, 22.55833333, 22.15833333, 21.225, 21.19166667, 21.59166667,
    22.025, 22.30833333, 22.10833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    23.42, 21.91, 21.92, 21.51, 21.69, 21.5, 21.5, 21.86, 21.79, 22.69,
    21.71, 21.36, 21.04, 21.68, 22.8, 22.33, 21.48, 22.16, 22.91, 24.44,
    22.63, 21.23, 20.03, 21.33, 21.25, 21.83, 21.05, 21.82, 21.47, 20.9,
    20.64, 20.69, 20.69, 20.67, 22.44, 22.38, 21.99, 20.86, 21.11, 21.5,
    21.57, 22.23, 21.9
])

# Plot the graph using vector graphics (PDF format)
plt.figure(figsize=(8, 4))  # Adjusted figure size
plt.plot(actual_temps, label='Actual Minimum Average Temperatures (2022)')
plt.plot(predicted_temps, label='Predicted Minimum Average Temperatures (1981-2010)')
plt.xlabel('Different Stations')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Minimum Average Temperatures')
plt.legend()
plt.tight_layout()

# Save the figure in PDF format with a specific name
plt.savefig('Fig01-temperature_comparison.pdf', format='pdf', dpi=400)  # Increased dpi for better quality

# Display the figure
plt.show()

# Figure caption
figure_caption = "Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010."
print(f"\nFigure 1: {figure_caption}")
# Out:
# Figure 1: Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    23.13333333, 21.68333333, 21.85833333, 21.50833333, 21.84166667,
    21.44166667, 21.44166667, 21.65833333, 21.5, 22.625, 21.80833333,
    21.09166667, 21.04166667, 21.725, 22.70833333, 22.4, 21.54166667,
    22.18333333, 22.81666667, 22.675, 22.39166667, 21.08333333, 20.13333333,
    21.23333333, 21.18333333, 21.86666667, 20.825, 21.83333333, 21.10833333,
    20.69166667, 20.45833333, 19.83333333, 20.58333333, 20.28333333,
    22.54166667, 22.55833333, 22.15833333, 21.225, 21.19166667, 21.59166667,
    22.025, 22.30833333, 22.10833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    23.42, 21.91, 21.92, 21.51, 21.69, 21.5, 21.5, 21.86, 21.79, 22.69,
    21.71, 21.36, 21.04, 21.68, 22.8, 22.33, 21.48, 22.16, 22.91, 24.44,
    22.63, 21.23, 20.03, 21.33, 21.25, 21.83, 21.05, 21.82, 21.47, 20.9,
    20.64, 20.69, 20.69, 20.67, 22.44, 22.38, 21.99, 20.86, 21.11, 21.5,
    21.57, 22.23, 21.9
])

# Plot the graph using vector graphics (PDF format)
plt.figure(figsize=(4.72, 2.36))  # Adjusted figure size in inches (12 cm x 6 cm)
plt.plot(actual_temps, label='Actual (2022)')
plt.plot(predicted_temps, label='Predicted (1981-2010)')
plt.xlabel('Different Stations', fontsize=8)  # Set font size for the x-axis label
plt.ylabel('Temperature', fontsize=8)  # Set font size for the y-axis label
plt.title('Actual vs Predicted Minimum Average Temperatures', fontsize=9)  # Set font size for the title
plt.legend(fontsize=8)  # Set font size for the legend
plt.tight_layout()

# Save the figure in PDF format with a specific name
plt.savefig('Fig01-1570983692.pdf', format='pdf', dpi=400)  # Increased dpi for better quality

# Display the figure
plt.show()

# Figure caption
figure_caption = "Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010."
print(f"\nFigure 1: {figure_caption}")
# Out:
# Figure 1: Comparison of actual minimum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Assuming you have an array of station indices
stations = np.arange(len(actual_temps))

# Create a 3D plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the actual temperatures
ax.scatter(stations, actual_temps, zs=0, label='Actual Minimum Average Temperatures (2022)')

# Plot the predicted temperatures
ax.scatter(stations, predicted_temps, zs=1, label='Predicted Minimum Average Temperatures (1981-2010)')

# Set labels and title
ax.set_xlabel('Station Index')
ax.set_ylabel('Temperature')
ax.set_zlabel('Actual vs Predicted')
ax.set_title('Actual vs Predicted Minimum Average Temperatures for Different Stations')

# Add a legend
ax.legend()

# Show the 3D plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    31.65833333, 31.225, 31.45833333,
    31.09166667, 31.11666667, 30.50833333, 30.53333333, 30.425, 30.4,
    31.36666667, 31.53333333, 32.35833333, 31.41666667, 31.25833333, 31.725,
    31.325, 31.50833333, 31.23333333, 31.33333333, 31.16666667, 31.56666667,
    30.61666667, 31.36666667, 31.76666667, 31.76666667, 31.11666667, 30.56666667,
    30.98333333, 30.38333333, 30.58333333, 30.875, 30.25, 29.79166667,
    29.81666667, 31.65833333, 31.65, 31.325, 31.75833333, 31.6, 31.41666667,
    31.575, 31.5, 31.40833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    32.21, 31.83, 32.03, 31.4, 31.49, 31.22, 31.25,
    31.21, 31.43, 31.75, 32.33, 35.13, 32.34, 31.88, 32.25, 31.86, 32.2,
    31.92, 31.74, 31.58, 31.71, 31.56, 31.8, 32.38, 32.52, 32.09, 31.38,
    31.26, 31.41, 31.75, 32.07, 31.42, 30.81, 31.12, 32.06, 31.89, 31.66,
    31.9, 32.15, 32.28, 32, 31.92, 31.8
])

# Plot the graph
plt.plot(actual_temps, label='Actual Maximum Average Temperatures (2022)')
plt.plot(predicted_temps, label='Predicted Maximum Average Temperatures(1981-2010)')
plt.xlabel('Different Stations')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Maximum Average Temperatures')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    31.65833333, 31.225, 31.45833333,
    31.09166667, 31.11666667, 30.50833333, 30.53333333, 30.425, 30.4,
    31.36666667, 31.53333333, 32.35833333, 31.41666667, 31.25833333, 31.725,
    31.325, 31.50833333, 31.23333333, 31.33333333, 31.16666667, 31.56666667,
    30.61666667, 31.36666667, 31.76666667, 31.76666667, 31.11666667, 30.56666667,
    30.98333333, 30.38333333, 30.58333333, 30.875, 30.25, 29.79166667,
    29.81666667, 31.65833333, 31.65, 31.325, 31.75833333, 31.6, 31.41666667,
    31.575, 31.5, 31.40833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    32.21, 31.83, 32.03, 31.4, 31.49, 31.22, 31.25,
    31.21, 31.43, 31.75, 32.33, 35.13, 32.34, 31.88, 32.25, 31.86, 32.2,
    31.92, 31.74, 31.58, 31.71, 31.56, 31.8, 32.38, 32.52, 32.09, 31.38,
    31.26, 31.41, 31.75, 32.07, 31.42, 30.81, 31.12, 32.06, 31.89, 31.66,
    31.9, 32.15, 32.28, 32, 31.92, 31.8
])

# Plot the graph using vector graphics (PDF format)
plt.figure(figsize=(10, 6))
plt.plot(actual_temps, label='Actual Maximum Average Temperatures (2022)')
plt.plot(predicted_temps, label='Predicted Maximum Average Temperatures(1981-2010)')
plt.xlabel('Different Stations')
plt.ylabel('Temperature')
plt.title('Actual vs Predicted Maximum Average Temperatures')
plt.legend()
plt.tight_layout()

# Save the figure in PDF format
plt.savefig('temperature_comparison.pdf', format='pdf')

# Display the figure
plt.show()

# Figure caption
figure_caption = "Comparison of actual maximum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010."
print(f"\nFigure 1: {figure_caption}")
# Out:
# Figure 1: Comparison of actual maximum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Actual temperature values for 2022
actual_temps = np.array([
    31.65833333, 31.225, 31.45833333,
    31.09166667, 31.11666667, 30.50833333, 30.53333333, 30.425, 30.4,
    31.36666667, 31.53333333, 32.35833333, 31.41666667, 31.25833333, 31.725,
    31.325, 31.50833333, 31.23333333, 31.33333333, 31.16666667, 31.56666667,
    30.61666667, 31.36666667, 31.76666667, 31.76666667, 31.11666667, 30.56666667,
    30.98333333, 30.38333333, 30.58333333, 30.875, 30.25, 29.79166667,
    29.81666667, 31.65833333, 31.65, 31.325, 31.75833333, 31.6, 31.41666667,
    31.575, 31.5, 31.40833333
])

# Predicted temperature values based on 1981-2010
predicted_temps = np.array([
    32.21, 31.83, 32.03, 31.4, 31.49, 31.22, 31.25,
    31.21, 31.43, 31.75, 32.33, 35.13, 32.34, 31.88, 32.25, 31.86, 32.2,
    31.92, 31.74, 31.58, 31.71, 31.56, 31.8, 32.38, 32.52, 32.09, 31.38,
    31.26, 31.41, 31.75, 32.07, 31.42, 30.81, 31.12, 32.06, 31.89, 31.66,
    31.9, 32.15, 32.28, 32, 31.92, 31.8
])

# Plot the graph using vector graphics (PDF format)
plt.figure(figsize=(4.72, 2.36))  # Adjusted figure size in inches (12 cm x 6 cm)
plt.plot(actual_temps, label='Actual (2022)')
plt.plot(predicted_temps, label='Predicted (1981-2010)')
plt.xlabel('Different Stations', fontsize=8)  # Set font size for the x-axis label
plt.ylabel('Temperature', fontsize=8)  # Set font size for the y-axis label
plt.title('Actual vs Predicted Maximum Average Temperatures', fontsize=9)  # Set font size for the title
plt.legend(fontsize=8)  # Set font size for the legend
plt.tight_layout()

# Save the figure in PDF format with a specific name
plt.savefig('Fig02-1570983692.pdf', format='pdf', dpi=400)  # Increased dpi for better quality

# Display the figure
plt.show()

# Figure caption
figure_caption = "Comparison of actual maximum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010."
print(f"\nFigure 1: {figure_caption}")
# Out:
# Figure 1: Comparison of actual maximum average temperatures for the year 2022 with predicted temperatures based on the period 1981-2010.
